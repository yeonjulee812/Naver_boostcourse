# %% [markdown]
# ## 데이터 분석 준비하기

# %%
# %pwd
# Out:
# 'C:\\Python\\Naver_Boostcourse'

# %%
import os
os.getcwd()
# Out:
# 'C:\\Python\\Naver_Boostcourse'

# %%
os.getcwd()
# Out:
# 'C:\\Python\\Naver_Boostcourse'

# %%
from glob import glob

file_name = glob('data/*.csv')[0]
file_name
# Out:
# 'data\\도로교통공단_월별 주야별 교통사고 통계_20211231.csv'

# %%
import pandas as pd
pd.read_csv(file_name, encoding='cp949')
#UnicodeDecodeError -> encoding='cp949' 삽입
#한글 윈도우에서 사용되는 인코딩 방식
# Out:
#     발생월 주야   사고건수  사망자수  중상자수   경상자수  부상신고자수
# 0     1  주   8821   107  2421   9631     707
# 1     1  야   6088    90  1627   6510     427
# 2     2  주   8756   107  2468   9681     670
# 3     2  야   5755    96  1572   6286     483
# 4     3  주  10274   128  2787  11163     820
# 5     3  야   6326    81  1775   6859     524
# 6     4  주  11032   119  3105  11935     819
# 7     4  야   6371    93  1878   6887     518
# 8     5  주  11025   154  3010  12132     922
# 9     5  야   6353   101  1762   6779     520
# 10    6  주  11310   124  3286  12244     865
# 11    6  야   6265   103  1733   6593     569
# 12    7  주  11408   139  3132  12435     892
# 13    7  야   6586   115  1829   7024     558
# 14    8  주  10407   129  2878  11541     854
# 15    8  야   6011   118  1638   6365     506
# 16    9  주  10869   131  2959  11885     856
# 17    9  야   6143   115  1747   6299     506
# 18   10  주  11229   156  3064  12129     882
# 19   10  야   7071   156  1935   7732     565
# ...

# %%
file_csv = glob('data/store/*_*_*.csv')
file_csv
# Out:
# ['data/store\\소상공인시장진흥공단_상가(상권)정보_강원_202209.csv',
#  'data/store\\소상공인시장진흥공단_상가(상권)정보_경기_202209.csv',
#  'data/store\\소상공인시장진흥공단_상가(상권)정보_경남_202209.csv',
#  'data/store\\소상공인시장진흥공단_상가(상권)정보_경북_202209.csv',
#  'data/store\\소상공인시장진흥공단_상가(상권)정보_광주_202209.csv',
#  'data/store\\소상공인시장진흥공단_상가(상권)정보_대구_202209.csv',
#  'data/store\\소상공인시장진흥공단_상가(상권)정보_대전_202209.csv',
#  'data/store\\소상공인시장진흥공단_상가(상권)정보_부산_202209.csv',
#  'data/store\\소상공인시장진흥공단_상가(상권)정보_서울_202209.csv',
#  'data/store\\소상공인시장진흥공단_상가(상권)정보_세종_202209.csv',
#  'data/store\\소상공인시장진흥공단_상가(상권)정보_울산_202209.csv',
#  'data/store\\소상공인시장진흥공단_상가(상권)정보_인천_202209.csv',
#  'data/store\\소상공인시장진흥공단_상가(상권)정보_전남_202209.csv',
#  'data/store\\소상공인시장진흥공단_상가(상권)정보_전북_202209.csv',
#  'data/store\\소상공인시장진흥공단_상가(상권)정보_제주_202209.csv',
#  'data/store\\소상공인시장진흥공단_상가(상권)정보_충남_202209.csv',
#  'data/store\\소상공인시장진흥공단_상가(상권)정보_충북_202209.csv']

# %%
#pd.read_csv(file_csv[0]) -- 인코딩 필요없이 잘 불러와지는지 확인

# %%
file_list =[]
for file_csv_name in file_csv:
    print(file_csv_name)
    temp = pd.read_csv(file_csv_name, low_memory=False)
    file_list.append(temp)
# Out:
# data/store\소상공인시장진흥공단_상가(상권)정보_강원_202209.csv
# data/store\소상공인시장진흥공단_상가(상권)정보_경기_202209.csv
# data/store\소상공인시장진흥공단_상가(상권)정보_경남_202209.csv
# data/store\소상공인시장진흥공단_상가(상권)정보_경북_202209.csv
# data/store\소상공인시장진흥공단_상가(상권)정보_광주_202209.csv
# data/store\소상공인시장진흥공단_상가(상권)정보_대구_202209.csv
# data/store\소상공인시장진흥공단_상가(상권)정보_대전_202209.csv
# data/store\소상공인시장진흥공단_상가(상권)정보_부산_202209.csv
# data/store\소상공인시장진흥공단_상가(상권)정보_서울_202209.csv
# data/store\소상공인시장진흥공단_상가(상권)정보_세종_202209.csv
# data/store\소상공인시장진흥공단_상가(상권)정보_울산_202209.csv
# data/store\소상공인시장진흥공단_상가(상권)정보_인천_202209.csv
# data/store\소상공인시장진흥공단_상가(상권)정보_전남_202209.csv
# data/store\소상공인시장진흥공단_상가(상권)정보_전북_202209.csv
# data/store\소상공인시장진흥공단_상가(상권)정보_제주_202209.csv
# data/store\소상공인시장진흥공단_상가(상권)정보_충남_202209.csv
# data/store\소상공인시장진흥공단_상가(상권)정보_충북_202209.csv

# %%
file_list[0]
# Out:
#           상가업소번호            상호명    지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       25033300      동그라미중고타이어    NaN         D       소매       D23
# 1       17174549  세인트존스호텔Ohcrab    NaN         O       숙박       O01
# 2       17174079        평창라마다호텔    NaN         O       숙박       O01
# 3       17173904    호텔탑스텐스카이라운지    NaN         O       숙박       O01
# 4       24412526          레이디가구    NaN         D       소매       D15
# ...          ...            ...    ...       ...      ...       ...
# 108394  18767035            빽다방  철원동송점         Q       음식       Q12
# 108395  18756448        프로타이어매장    NaN         F    생활서비스       F14
# 108396  18761043          피투에이치    NaN         F    생활서비스       F01
# 108397  18755510           미르건축    NaN         F    생활서비스       F15
# 108398  18765328           아르블랑    NaN         F    생활서비스       F01
#
#          상권업종중분류명 상권업종소분류코드     상권업종소분류명 표준산업분류코드  ...  \
# 0       자동차/자동차용품    D23A04        타이어판매   G45211  ...
# ...

# %%
len(file_list)
# Out:
# 17

# %%
df = pd.concat(file_list)
df.shape
# Out:
# (2446771, 39)

# %%
df.head()
# Out:
#      상가업소번호            상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드   상권업종중분류명  \
# 0  25033300      동그라미중고타이어  NaN         D       소매       D23  자동차/자동차용품
# 1  17174549  세인트존스호텔Ohcrab  NaN         O       숙박       O01      호텔/콘도
# 2  17174079        평창라마다호텔  NaN         O       숙박       O01      호텔/콘도
# 3  17173904    호텔탑스텐스카이라운지  NaN         O       숙박       O01      호텔/콘도
# 4  24412526          레이디가구  NaN         D       소매       D15       가구소매
#
#   상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호      건물명  \
# 0    D23A04    타이어판매   G45211  ...  4215011100110960006010791      NaN
# 1    O01A01    호텔/콘도      NaN  ...  4215011300100010001017124  세인트존스호텔
# 2    O01A01    호텔/콘도      NaN  ...  4276038024102450036000001      NaN
# 3    O01A01    호텔/콘도      NaN  ...  4215035029100920001000002      NaN
# 4    D15A01   일반가구소매   G47520  ...  4213011500111400020035715      NaN
#
#                            도로명주소     구우편번호  신우편번호  동정보  층정보  호정보          경도  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2446771 entries, 0 to 94171
# Data columns (total 39 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   상가업소번호     int64
#  1   상호명        object
#  2   지점명        object
#  3   상권업종대분류코드  object
#  4   상권업종대분류명   object
#  5   상권업종중분류코드  object
#  6   상권업종중분류명   object
#  7   상권업종소분류코드  object
#  8   상권업종소분류명   object
#  9   표준산업분류코드   object
#  10  표준산업분류명    object
#  11  시도코드       int64
#  12  시도명        object
#  13  시군구코드      int64
#  14  시군구명       object
#  15  행정동코드      int64
#  16  행정동명       object
#  17  법정동코드      int64
#  18  법정동명       object
#  19  지번코드       int64
#  20  대지구분코드     int64
#  21  대지구분명      object
#  22  지번본번지      int64
#  23  지번부번지      float64
#  24  지번주소       object
#  25  도로명코드      int64
#  26  도로명        object
#  27  건물본번지      int64
#  28  건물부번지      float64
#  29  건물관리번호     object
#  30  건물명        object
#  31  도로명주소      object
#  32  구우편번호      float64
# ...
